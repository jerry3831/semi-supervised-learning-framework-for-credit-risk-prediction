# %%
import pandas as pd
import numpy as np
from imblearn.over_sampling import SMOTE

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data = pd.read_excel('datasetv1-1.xlsx')

# %%
data.shape
# Out:
# (355, 30)

# %%
data.head()
# Out:
#   age_range  gender marital_status    region highest_education school  \
# 0  38 to 48    Male        Married  Southern            Master   Poly
# 1  28 to 37  Female         Single   Central            Master   Poly
# 2  28 to 37    Male        Married   Central            Master   Poly
# 3  28 to 37  Female        Married  Southern            Master   Poly
# 4  28 to 37    Male        Married   Central          Bachelor   Poly
#
#    graduation study_programme  employment_status  last_year_benefitted  \
# 0      2004.0     Accountancy  Employed_fulltime                  2004
# 1      2014.0     Accountancy  Employed_fulltime                  2014
# 2      2014.0     Accountancy  Employed_fulltime                  2013
# 3      2012.0     Accountancy  Employed_fulltime                  2011
# 4      2016.0     Accountancy  Employed_fulltime                  2015
#
#                     total_loan               loan_purpose repayment_status  \
# 0        Less than MWK 200,000  Tuition_Living_Stationery       Fully_paid
# 1    MWK 300,001 – MWK 500,000  Tuition_Living_Stationery       Fully_paid
# 2  MWK 600,001 – MWK 1,000,000             Tuition_Living       Fully_paid
# 3  MWK 600,001 – MWK 1,000,000             Tuition_Living       Fully_paid
# 4  MWK 600,001 – MWK 1,000,000  Tuition_Living_Stationery       Fully_paid
#
#   informed_repayment_obligations repayment_info_source repayment_method  \
# 0                            NaN             CRBreport           oneoff
# 1                            NaN              Employer   monthly_salary
# 2                            NaN       Email_Phonecall   monthly_salary
# 3                            NaN    Phonecall_Inperson   monthly_salary
# 4                            NaN    Phonecall_Inperson   monthly_salary
#
#   repayment_method_convenience effectiveness_repayment_method  \
# 0                      neutral                    ineffective
# 1                   convenient                    ineffective
# 2              very_convenient                 very_effective
# 3              very_convenient                 very_effective
# 4              very_convenient                 very_effective
#
#   any_loan_repayment_challenges  \
# 0                           yes
# 1                            no
# 2                           yes
# 3                           yes
# 4                           yes
#
#                         loan_repayment_challenges  \
# 0   repayment_info_gap, lack_communication_HESLGB
# 1                                   no_challenges
# 2  lack_communication_HESLGB, high_interest_rates
# 3  lack_communication_HESLGB, high_interest_rates
# 4  lack_communication_HESLGB, high_interest_rates
#
#   collection_strategy_effectiveness  \
# 0                         effective
# 1                       ineffective
# 2                    very_effective
# 3                    very_effective
# 4                    very_effective
#
#                   factors_loan_repayment_performance  \
# 0  employment_status, repayment_terms_awareness, ...
# 1  employment_status, income_levels, economic_con...
# 2             employment_status, economic_conditions
# 3  employment_status, family_obligations, repayme...
# 4              employment_status, family_obligations
#
#                                 repayment_challenges  \
# 0             lacking_clear_comunication_from_HESLGB
# 1             lacking_clear_comunication_from_HESLGB
# 2  lacking_clear_comunication_from_HESLGB, high_c...
# 3              insufficient_income, high_cost_living
# 4                     unemployment, high_cost_living
#
#   interaction_quality_on_repayment suggested_collection_improvements  \
# 0                          neutral                               NaN
# 1                          neutral                               NaN
# 2                    very_positive                               NaN
# 3                    very_positive                               NaN
# 4                    very_positive                               NaN
#
#   tech_tools_improving_recovery any_alternative_collection_strategies  \
# 0                           NaN                                   NaN
# 1                           NaN                                   NaN
# 2                           NaN                                   NaN
# 3                           NaN                                   NaN
# 4                           NaN                                   NaN
#
#                    alternative_collection_strategies  \
# 0  Contact us via emails with CoMplete informatio...
# 1          Tracking system and better communication
# 2  Offer rewards for timely payments or early set...
# 3  Identify and address potential issues before t...
# 4  Identify and address potential issues before t...
#
#   overall_experience_with_loan_process  \
# 0                         Dissatisfied
# 1                         Dissatisfied
# 2                       Very satisfied
# 3                       Very satisfied
# 4                       Very satisfied
#
#                                      reCoMmendations
# 0  Improve communication and follow-up, Simplify ...
# 1  Improve communication and follow-up, Simplify ...
# 2              Provide more flexible repayment plans
# 3  Improve communication and follow-up, Reduce in...
# 4  Improve communication and follow-up, Provide m...

# %%
for column in data.columns:
    print(column)
# Out:
# age_range
# gender
# marital_status
# region
# highest_education
# school
# graduation
# study_programme
# employment_status
# last_year_benefitted
# total_loan
# loan_purpose
# repayment_status
# informed_repayment_obligations
# repayment_info_source
# repayment_method
# repayment_method_convenience
# effectiveness_repayment_method
# any_loan_repayment_challenges
# loan_repayment_challenges
# collection_strategy_effectiveness
# factors_loan_repayment_performance
# repayment_challenges
# interaction_quality_on_repayment
# suggested_collection_improvements
# tech_tools_improving_recovery
# any_alternative_collection_strategies
# alternative_collection_strategies
# overall_experience_with_loan_process
# reCoMmendations

# %%
data.dtypes
# Out:
# age_range                                 object
# gender                                    object
# marital_status                            object
# region                                    object
# highest_education                         object
# school                                    object
# graduation                               float64
# study_programme                           object
# employment_status                         object
# last_year_benefitted                       int64
# total_loan                                object
# loan_purpose                              object
# repayment_status                          object
# informed_repayment_obligations            object
# repayment_info_source                     object
# repayment_method                          object
# repayment_method_convenience              object
# effectiveness_repayment_method            object
# any_loan_repayment_challenges             object
# loan_repayment_challenges                 object
# collection_strategy_effectiveness         object
# factors_loan_repayment_performance        object
# repayment_challenges                      object
# interaction_quality_on_repayment          object
# suggested_collection_improvements         object
# tech_tools_improving_recovery             object
# any_alternative_collection_strategies     object
# alternative_collection_strategies         object
# overall_experience_with_loan_process      object
# reCoMmendations                           object
# dtype: object

# %%
sample_1 = data.sample(n=250, replace=True)

# %%
data.informed_repayment_obligations.unique()
# Out:
# array([nan, 'yes', 'no'], dtype=object)

# %%
# second sample
X = data.drop(columns='repayment_status')
y = data['repayment_status']

smote = SMOTE()
X_resampled, y_resampled = smote.fit(X, y)
df = pd.DataFrame(X_resampled, columns=X.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15764\1823609765.py in ?()
#       2 X = data.drop(columns='repayment_status')
#       3 y = data['repayment_status']
#       4
#       5 smote = SMOTE()
# ----> 6 X_resampled, y_resampled = smote.fit(X, y)
#       7 df = pd.DataFrame(X_resampled, columns=X.columns)
#
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\imblearn\base.py in ?(self, X, y, **params)
#     175         -------
#     176         self : object
#     177             Return the instance itself.
#     178         """
# --> 179         return super().fit(X, y, **params)
#
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\imblearn\base.py in ?(self, X, y, **params)
#      62         -------
#      63         self : object
#      64             Return the instance itself.
#      65         """
# ---> 66         X, y, _ = self._check_X_y(X, y)
#      67         self.sampling_strategy_ = check_sampling_strategy(
#      68             self.sampling_strategy, y, self._sampling_type
#      69         )
#
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\imblearn\base.py in ?(self, X, y, accept_sparse)
#     153     def _check_X_y(self, X, y, accept_sparse=None):
#     154         if accept_sparse is None:
#     155             accept_sparse = ["csr", "csc"]
#     156         y, binarize_y = check_target_type(y, indicate_one_vs_all=True)
# --> 157         X, y = validate_data(self, X=X, y=y, reset=True, accept_sparse=accept_sparse)
#     158         return X, y, binarize_y
#
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2957             if "estimator" not in check_y_params:
#    2958                 check_y_params = {**default_check_params, **check_y_params}
#    2959             y = check_array(y, input_name="y", **check_y_params)
#    2960         else:
# -> 2961             X, y = check_X_y(X, y, **check_params)
#    2962         out = X, y
#    2963
#    2964     if not no_val_X and check_params.get("ensure_2d", True):
#
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1366         )
#    1367
#    1368     ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
#    1369
# -> 1370     X = check_array(
#    1371         X,
#    1372         accept_sparse=accept_sparse,
#    1373         accept_large_sparse=accept_large_sparse,
#
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1052                         )
#    1053                     array = xp.astype(array, dtype, copy=False)
#    1054                 else:
#    1055                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1056             except ComplexWarning as complex_warning:
#    1057                 raise ValueError(
#    1058                     "Complex data not supported\n{}\n".format(array)
#    1059                 ) from complex_warning
#
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     835         # Use NumPy API to support order
#     836         if copy is True:
#     837             array = numpy.array(array, order=order, dtype=dtype)
#     838         else:
# --> 839             array = numpy.asarray(array, order=order, dtype=dtype)
#     840
#     841         # At this point array is a NumPy ndarray. We convert it to an array
#     842         # container that is consistent with the input's namespace.
#
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, dtype)
#    2082     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    2083         values = self._values
# -> 2084         arr = np.asarray(values, dtype=dtype)
#    2085         if (
#    2086             astype_is_view(values.dtype, arr.dtype)
#    2087             and using_copy_on_write()
#
# ValueError: could not convert string to float: '38 to 48'

# %%
metadata = pd.read_csv("dataset_metadata-1.csv", encoding='windows-1256')
metadata
# Out:
#                Column Name Data Type  \
# 0                     BAge     int64
# 1           BMaritalStatus    Object
# 2                BEduLevel    Object
# 3            Householdsize   float64
# 4               Dependents   float64
# 5                  BStateR     int64
# 6             BCreditScore     int64
# 7            CBCreditScore     int64
# 8              BTimeToComp     int64
# 9                   BMajor    Object
# 10                BCollege    Object
# 11        CollegeYrOfEntry     int64
# 12               BGradYear     int64
# 13        OntimeGraduation    Object
# 14                    BGPA   float64
# 15              BEmpStatus    Object
# 16  RegionUnemploymentRate   float64
# 17           Infrationrate   float64
# 18                GradRate   float64
# 19         CurrentLintRate   float64
# 20              OgLIntRate   float64
# 21                   LTerm     int64
# 22         Loangraceperiod     int64
# 23            LPaymentDate    Object
# 24           Repaymentplan    Object
# 25                   RTime     int64
# 26              ColEfforts    Object
# 27                 LAmount     int64
# 28            FPaymentDate    Object
# 29                   RAmnt     int64
# 30               DeliqDate    Object
# 31             DeliqStatus     int64
# 32             lossDefault     int64
#
#                                           Description
# 0                            Borrower's age in years.
# 1   Borrower's marital status (e.g., Married, Sing...
# 2   Borrower's education level (e.g., Undergraduat...
# 3      Number of members in the borrower's household.
# 4   Number of dependents the borrower supports fin...
# 5                       Borrower's region/state code.
# 6        Borrower's credit score at loan application.
# 7   Borrower's co-borrower's credit score, if appl...
# 8   Time (in years) the borrower took to complete ...
# 9   Borrower's academic major (e.g., Bachelor of S...
# 10     Name of the institution the borrower attended.
# 11                 Year the borrower entered college.
# 12                       Year the borrower graduated.
# 13  Indicates whether the borrower graduated on ti...
# 14      Borrower's grade point average at graduation.
# 15  Borrower's employment status (e.g., Employed, ...
# 16  Unemployment rate in the borrower's region at ...
# 17  Inflation rate during the borrower's loan appl...
# 18     Graduation rate of the borrower's institution.
# 19  Current loan interest rate applicable to the b...
# 20  Original loan interest rate at the time of dis...
# 21                                Loan term in years.
# 22  Grace period (in years) before loan repayment ...
# 23          Date of the borrower's last loan payment.
# 24  Borrower's repayment plan type (e.g., Salary, ...
# 25  Time (in months) borrower has been repaying th...
# 26  Collection efforts made by the lender (e.g., N...
# 27                  Loan amount originally disbursed.
# 28         Date of the borrower's first loan payment.
# 29  Total repayment amount made by the borrower to...
# 30  Date of loan delinquency occurrence, if applic...
# 31  Status of loan delinquency (1 = Delinquent, 0 ...
# 32                Loss given default as a percentage.
