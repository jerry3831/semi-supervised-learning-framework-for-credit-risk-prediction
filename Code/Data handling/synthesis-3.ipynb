# %%
import pandas as pd
import numpy as np 
from matplotlib import pyplot as plt

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
data = pd.read_csv('sample.csv')

# %%
data.isnull().sum()
# Out:
# gender                                  0
# marital_status                          0
# region                                  0
# highest_education                       0
# school                                  0
# graduation                              0
# study_programme                         0
# employment_status                       0
# last_year_benefitted                    0
# loan_purpose                            0
# repayment_status                        0
# repayment_info_source                   0
# repayment_method                        0
# repayment_method_convenience            0
# effectiveness_repayment_method          0
# collection_strategy_effectiveness       0
# interaction_quality_on_repayment        0
# alternative_collection_strategies       0
# overall_experience_with_loan_process    0
# age_group                               0
# over_under_milion                       0
# dtype: int64

# %%
data.sample(10)
# Out:
#      gender marital_status    region highest_education   school  graduation  \
# 15   female        married  southern          bachelor   chanco      2016.0
# 258    male         single  northern          bachelor     poly      2013.0
# 22   female        married  northern            master    mzuni      2008.0
# 209    male        married  southern          bachelor   chanco      2017.0
# 151  female        married   central          bachelor   chanco      2017.0
# 79   female         single  southern          bachelor  chanco       2015.0
# 0      male        married  southern            master     poly      2004.0
# 66     male        married   central         doctorate    mzuni      2012.0
# 165    male         single  southern          bachelor    mzuni      2014.0
# 212    male         single  southern          bachelor   chanco      2017.0
#
#                     study_programme  employment_status  last_year_benefitted  \
# 15                  arts_humanities  employed_fulltime                  2012
# 258                      journalism  employed_fulltime                  2012
# 22   theology_and_religious_studies  employed_fulltime                  2007
# 209               education_science      self_employed                  2016
# 151               education_science  employed_fulltime                  2016
# 79                education_science  employed_fulltime                  2014
# 0                       accountancy  employed_fulltime                  2004
# 66                   arts_education  employed_fulltime                  2012
# 165               education_science  employed_fulltime                  2013
# 212               education_science  employed_fulltime                  2016
#
#                   loan_purpose repayment_status repayment_info_source  \
# 15                  stationery       fully_paid              employer
# 258             tuition_living   partially_paid                 email
# 22              tuition_living       fully_paid              inperson
# 209             tuition_living         not_paid              inperson
# 151                     living         not_paid                 email
# 79              tuition_living       fully_paid       email_phonecall
# 0    tuition_living_stationery       fully_paid             crbreport
# 66              tuition_living       fully_paid    phonecall_inperson
# 165             tuition_living         not_paid        email_inperson
# 212             tuition_living         not_paid              inperson
#
#     repayment_method repayment_method_convenience  \
# 15    monthly_salary              very_convenient
# 258   monthly_salary                      neutral
# 22    monthly_salary                   convenient
# 209             none                 inconvenient
# 151             none                      neutral
# 79    monthly_salary              very_convenient
# 0             oneoff                      neutral
# 66    monthly_salary              very_convenient
# 165             none                   convenient
# 212             none                 inconvenient
#
#     effectiveness_repayment_method collection_strategy_effectiveness  \
# 15                  very_effective                         effective
# 258                        neutral                         effective
# 22                       effective                         effective
# 209                    ineffective                           neutral
# 151                        neutral                           neutral
# 79                  very_effective                    very_effective
# 0                      ineffective                         effective
# 66                  very_effective                    very_effective
# 165                      effective                         effective
# 212                    ineffective                           neutral
#
#     interaction_quality_on_repayment  \
# 15                          positive
# 258                         positive
# 22                          positive
# 209                          neutral
# 151                          neutral
# 79                     very_positive
# 0                            neutral
# 66                     very_positive
# 165                         positive
# 212                          neutral
#
#                      alternative_collection_strategies  \
# 15               digital tracking system through mno's
# 258                                clear communication
# 22               provide good communication strategies
# 209                                automate the system
# 151                                clear communication
# 79                          use of positive languages
# 0    contact us via emails with complete informatio...
# 66   work with borrowers to find mutually beneficia...
# 165            use social media to remainder borrowers
# 212                           accountability_reporting
#
#     overall_experience_with_loan_process age_group over_under_milion  \
# 15                               neutral   28 - 37             under
# 258                            satisfied   21 - 27             under
# 22                             satisfied   38 - 48              over
# 209                              neutral   28 - 37              over
# 151                              neutral   28 - 37             under
# 79                        very satisfied   21 - 27              over
# 0                           dissatisfied   38 - 48             under
# 66                        very satisfied   49 - 59             under
# 165                            satisfied   21 - 27              over
# 212                              neutral   28 - 37              over
#
#           discipline
# 15   arts_humanities
# 258       journalism
# 22          theology
# 209        education
# 151        education
# 79         education
# 0        accountancy
# 66         education
# 165        education
# 212        education

# %%
# attempted feature extraction
from tsfresh import extract_features

# Sample time series data with an id column
df['id'] = 1
df['time'] = range(len(df))

# Extract features using tsfresh
extracted_features = extract_features(df, column_id='id', column_sort='time')

print(extracted_features)
