# %%
import pandas as pd
import numpy as np 
from matplotlib import pyplot as plt

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
data = pd.read_csv('sample.csv')

# %%
data.isnull().sum()
# Out:
# gender                                  0
# marital_status                          0
# region                                  0
# highest_education                       0
# school                                  0
# graduation                              0
# study_programme                         0
# employment_status                       0
# last_year_benefitted                    0
# total_loan                              0
# loan_purpose                            0
# repayment_status                        0
# repayment_info_source                   0
# repayment_method                        0
# repayment_method_convenience            0
# effectiveness_repayment_method          0
# collection_strategy_effectiveness       0
# interaction_quality_on_repayment        0
# alternative_collection_strategies       0
# overall_experience_with_loan_process    0
# age_group                               0
# dtype: int64

# %%
data.sample(10)
# Out:
#      gender marital_status    region highest_education   school  graduation  \
# 57     male        married  southern          bachelor     poly      2016.0
# 115  female        married  northern          bachelor    mzuni      2015.0
# 234  female        married  northern            master     must      2015.0
# 161    male       divorced  northern         doctorate  chanco       2009.0
# 206    male         single   central          bachelor    mzuni      2011.0
# 319  female        married  southern          bachelor     com       2017.0
# 35   female        married  northern          bachelor   chanco      2017.0
# 30     male        married  northern          bachelor    mzuni      2013.0
# 216  female        widowed   central            master    mzuni      2016.0
# 140  female        married  southern          bachelor  mancosa      2013.0
#
#                     study_programme  employment_status  last_year_benefitted  \
# 57          business_administration  employed_parttime                  2015
# 115              biomedical_science  employed_fulltime                  2014
# 234                       dentistry  employed_fulltime                  2014
# 161               education_science  employed_fulltime                  2008
# 206               education_science  employed_fulltime                  2010
# 319                        pharmacy  employed_parttime                  2016
# 35   theology_and_religious_studies  employed_fulltime                  2016
# 30   theology_and_religious_studies  employed_fulltime                  2012
# 216     human_resource_development_  employed_fulltime                  2015
# 140         business_administration  employed_fulltime                  2012
#
#                       total_loan               loan_purpose repayment_status  \
# 57   mwk 600,001 – mwk 1,000,000             tuition_living         not_paid
# 115    mwk 300,001 – mwk 500,000             tuition_living       fully_paid
# 234  mwk 600,001 – mwk 1,000,000                     living       fully_paid
# 161  mwk 600,001 – mwk 1,000,000                     living       fully_paid
# 206           above mwk1,000,000             tuition_living         not_paid
# 319  mwk 600,001 – mwk 1,000,000                    tuition         not_paid
# 35   mwk 600,001 – mwk 1,000,000                    tuition         not_paid
# 30            above mwk1,000,000  tuition_living_stationery   partially_paid
# 216           above mwk1,000,000  tuition_living_stationery       fully_paid
# 140           above mwk1,000,000             tuition_living         not_paid
#
#     repayment_info_source repayment_method repayment_method_convenience  \
# 57                  email             none                      neutral
# 115       email_phonecall   monthly_salary                   convenient
# 234                 email   monthly_salary                   convenient
# 161             phonecall   monthly_salary                      neutral
# 206              inperson             none                 inconvenient
# 319              inperson             none                      neutral
# 35               inperson             none                 inconvenient
# 30                  email   monthly_salary                 inconvenient
# 216                  none   monthly_salary              very_convenient
# 140                  none             none                   convenient
#
#     effectiveness_repayment_method collection_strategy_effectiveness  \
# 57                         neutral                           neutral
# 115                      effective                         effective
# 234                      effective                         effective
# 161                      effective                         effective
# 206                    ineffective                           neutral
# 319                        neutral                           neutral
# 35                     ineffective                           neutral
# 30                     ineffective                           neutral
# 216                      effective                    very_effective
# 140                        neutral                       ineffective
#
#     interaction_quality_on_repayment  \
# 57                           neutral
# 115                         positive
# 234                         positive
# 161                         positive
# 206                          neutral
# 319                          neutral
# 35                           neutral
# 30                           neutral
# 216                          neutral
# 140                          neutral
#
#                      alternative_collection_strategies  \
# 57                                 clear communication
# 115  work with borrowers to find matually beneficia...
# 234            develop a succession planning strategy
# 161                                automate the system
# 206                                automate the system
# 319                             improve communication
# 35                                 automate the system
# 30                            accountability_reporting
# 216   use of automated system linked to banks accounts
# 140  put in place security measures of collecting t...
#
#     overall_experience_with_loan_process age_group
# 57                               neutral   28 - 37
# 115                            satisfied   38 - 48
# 234                            satisfied   28 - 37
# 161                            satisfied   38 - 48
# 206                            satisfied   28 - 37
# 319                              neutral   28 - 37
# 35                               neutral   38 - 48
# 30                               neutral   28 - 37
# 216                            satisfied   49 - 59
# 140                              neutral   28 - 37

# %%
# attempted feature extraction
from tsfresh import extract_features

# Sample time series data with an id column
df['id'] = 1
df['time'] = range(len(df))

# Extract features using tsfresh
extracted_features = extract_features(df, column_id='id', column_sort='time')

print(extracted_features)
